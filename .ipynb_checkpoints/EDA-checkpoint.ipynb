# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Cleaned_Salary.csv')

# %%
df.columns
# Out:
# Index(['title', 'company', 'location', 'salary', 'rating', 'hourly', 'min_sal',
#        'max_sal', 'avg_salary', 'city', 'state'],
#       dtype='object')

# %%
df.shape
# Out:
# (605, 11)

# %%
df['title']
# Out:
# 0                                    Risk Data Scientist
# 1                               Associate Data Scientist
# 2                                         Data Scientist
# 3                                   Data Scientist I, II
# 4                                         Data Scientist
#                              ...
# 600                       Senior Data Scientist (AdTech)
# 601    Junior Research Engineer - Machine Learning Sy...
# 602                                Senior Data Scientist
# 603      Machine Learning Engineer - Foundational Models
# 604                 Biomedical Machine Learning Engineer
# Name: title, Length: 605, dtype: object

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    elif 'research' in title.lower():
        return 'research position'    
    else:
        return 'na'
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp']=df['title'].apply(title_simplifier)

# %%
df.job_simp.head()
# Out:
# 0    data scientist
# 1    data scientist
# 2    data scientist
# 3    data scientist
# 4    data scientist
# Name: job_simp, dtype: object

# %%
df.job_simp.value_counts()
# Out:
# job_simp
# data scientist       552
# na                    23
# mle                   16
# analyst                9
# research position      3
# data engineer          1
# manager                1
# Name: count, dtype: int64

# %%
df['job_seniority']=df.title.apply(seniority)

# %%
df['job_seniority'].value_counts()
# Out:
# job_seniority
# na        453
# senior    150
# jr          2
# Name: count, dtype: int64

# %%
df.state.value_counts()
# Out:
# state
#  CA       137
# Remote     96
#  NY        42
#  TX        39
#  VA        33
#  IL        24
#  OH        22
#  WA        20
#  GA        20
#  NJ        19
#  CO        19
#  DC        19
#  MD        14
#  PA        13
#  MA        11
#  UT         9
#  AZ         7
#  FL         7
#  NC         6
#  IN         5
#  PR         4
#  AR         4
#  MN         4
#  MO         4
#  MI         3
#  WI         3
#  TN         3
#  NV         2
#  NM         2
#  AL         2
#  SC         2
#  LA         1
#  NH         1
#  OK         1
#  IA         1
#  KY         1
#  OR         1
#  CT         1
#  NE         1
#  ME         1
#  HI         1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['title', 'company', 'location', 'salary', 'rating', 'hourly', 'min_sal',
#        'max_sal', 'avg_salary', 'city', 'state', 'job_simp', 'job_seniority'],
#       dtype='object')

# %%
df.min_sal=df.apply(lambda x : x.min_sal * 2 if x.hourly==1 else x.min_sal, axis=1)
df.max_sal=df.apply(lambda x : x.max_sal * 2 if x.hourly==1 else x.max_sal, axis=1)

# %%
df.loc[df['hourly'] == 1, ['hourly', 'min_sal', 'max_sal','city','company']]
# Out:
#      hourly  min_sal  max_sal                city  \
# 5         1   160.00   180.00              Remote
# 73        1    50.00    80.00       United States
# 79        1    50.00   200.00       United States
# 84        1   170.00   180.00           Sunnyvale
# 88        1   110.22   124.00              Dallas
# 131       1   100.08   130.00         Santa Clara
# 145       1   180.00   200.00     Deerfield Beach
# 157       1   100.00   100.00             Malvern
# 158       1    33.66   151.26              Austin
# 169       1    70.00    80.00           Cambridge
# 213       1   142.00   150.00             Atlanta
# 214       1   150.00   159.72              Summit
# 231       1   152.00   160.00             Atlanta
# 254       1   150.00   160.00              Remote
# 305       1   112.46   168.70           San Diego
# 335       1   100.00   120.00             Phoenix
# 343       1   220.00   288.00              Remote
# 347       1   110.00   120.00             Peapack
# 353       1   160.00   180.00           San Mateo
# 381       1    16.00   130.00              Remote
# 382       1   140.68   224.62            Bethesda
# 395       1    28.00    28.00       United States
# 428       1   160.00   160.00             Atlanta
# 429       1    83.22   130.02              Camden
# 430       1   112.90   135.96            Richmond
# 457       1    41.20    82.40              Gretna
# 460       1   168.28   192.32  Annapolis Junction
# 464       1   100.00   200.00       United States
# 476       1   119.90   150.52             Atlanta
# 478       1   111.28   131.42   Greenwood Village
# 482       1   110.26   132.78              Austin
# 484       1   130.00   150.00              Dallas
# 489       1   156.00   166.00          Pennington
# 505       1   108.24   130.34              Remote
# 515       1   110.00   120.00              Dallas
# 527       1   150.52   150.52             Atlanta
# 543       1    88.30   106.34             Raleigh
# 556       1   113.06   136.16             Houston
# 586       1   130.00   160.00             Atlanta
#
#                                     company
# 5                             GenuineXs LLC
# 73               Continuum Resource Network
# 79                       Oland Technologies
# 84                                  Skyelia
# 88            Pebal Bright Technologies LLC
# 131                 Hecta Data (DBA) Vilwaa
# 145                          CTI Consulting
# 157                         Intone Networks
# 158                 Amazon.com Services LLC
# 169                                  Pfizer
# 213                                TMS, LLC
# 214                   Stage 4 Solutions Inc
# 231                                 DevCare
# 254                     Veear Projects Inc.
# 305                                Qualcomm
# 335                             Freelancing
# 343                                  Sanofi
# 347                                  Kaygen
# 353                                    Vivo
# 381                        Invisible Agency
# 382   University of Maryland Medical System
# 395                         TELUS Digital -
# 428             Changing Technologies, Inc.
# 429                               Capgemini
# 430                          Infoorigin inc
# 457                                  Abbott
# 460                               Everwatch
# 464                           Finoptics LLC
# 476                             Info Origin
# 478                   NextGen | GTA Telecom
# 482                             Hanosys.inc
# 484                        Select Minds LLC
# 489                     Career Mentors, LLC
# 505                             Hanosys.inc
# 515                               1Fivetech
# 527  Techmorgonite Software Solutions, LLC.
# 543                            Dataquad Inc
# 556                             Hanosys.inc
# 586                                   Loyal

# %%
temp=pd.read_csv('Cleaned_Salary.csv')

# %%
temp.loc[temp['hourly'] == 1, ['hourly', 'min_sal', 'max_sal','city','company']]
# Out:
#      hourly  min_sal  max_sal                city  \
# 5         1    80.00    90.00              Remote
# 73        1    25.00    40.00       United States
# 79        1    25.00   100.00       United States
# 84        1    85.00    90.00           Sunnyvale
# 88        1    55.11    62.00              Dallas
# 131       1    50.04    65.00         Santa Clara
# 145       1    90.00   100.00     Deerfield Beach
# 157       1    50.00    50.00             Malvern
# 158       1    16.83    75.63              Austin
# 169       1    35.00    40.00           Cambridge
# 213       1    71.00    75.00             Atlanta
# 214       1    75.00    79.86              Summit
# 231       1    76.00    80.00             Atlanta
# 254       1    75.00    80.00              Remote
# 305       1    56.23    84.35           San Diego
# 335       1    50.00    60.00             Phoenix
# 343       1   110.00   144.00              Remote
# 347       1    55.00    60.00             Peapack
# 353       1    80.00    90.00           San Mateo
# 381       1     8.00    65.00              Remote
# 382       1    70.34   112.31            Bethesda
# 395       1    14.00    14.00       United States
# 428       1    80.00    80.00             Atlanta
# 429       1    41.61    65.01              Camden
# 430       1    56.45    67.98            Richmond
# 457       1    20.60    41.20              Gretna
# 460       1    84.14    96.16  Annapolis Junction
# 464       1    50.00   100.00       United States
# 476       1    59.95    75.26             Atlanta
# 478       1    55.64    65.71   Greenwood Village
# 482       1    55.13    66.39              Austin
# 484       1    65.00    75.00              Dallas
# 489       1    78.00    83.00          Pennington
# 505       1    54.12    65.17              Remote
# 515       1    55.00    60.00              Dallas
# 527       1    75.26    75.26             Atlanta
# 543       1    44.15    53.17             Raleigh
# 556       1    56.53    68.08             Houston
# 586       1    65.00    80.00             Atlanta
#
#                                     company
# 5                             GenuineXs LLC
# 73               Continuum Resource Network
# 79                       Oland Technologies
# 84                                  Skyelia
# 88            Pebal Bright Technologies LLC
# 131                 Hecta Data (DBA) Vilwaa
# 145                          CTI Consulting
# 157                         Intone Networks
# 158                 Amazon.com Services LLC
# 169                                  Pfizer
# 213                                TMS, LLC
# 214                   Stage 4 Solutions Inc
# 231                                 DevCare
# 254                     Veear Projects Inc.
# 305                                Qualcomm
# 335                             Freelancing
# 343                                  Sanofi
# 347                                  Kaygen
# 353                                    Vivo
# 381                        Invisible Agency
# 382   University of Maryland Medical System
# 395                         TELUS Digital -
# 428             Changing Technologies, Inc.
# 429                               Capgemini
# 430                          Infoorigin inc
# 457                                  Abbott
# 460                               Everwatch
# 464                           Finoptics LLC
# 476                             Info Origin
# 478                   NextGen | GTA Telecom
# 482                             Hanosys.inc
# 484                        Select Minds LLC
# 489                     Career Mentors, LLC
# 505                             Hanosys.inc
# 515                               1Fivetech
# 527  Techmorgonite Software Solutions, LLC.
# 543                            Dataquad Inc
# 556                             Hanosys.inc
# 586                                   Loyal

# %%
temp.min_sal=temp.apply(lambda x : x.min_sal * 2 if x.hourly==1 else x.min_sal, axis=1)

# %%
temp.max_sal=temp.apply(lambda x : x.max_sal * 2 if x.hourly==1 else x.max_sal, axis=1)

# %%
df.min_sal=temp.min_sal

# %%
df.max_sal=temp.max_sal

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                  title  \
# 0                                  Risk Data Scientist
# 1                             Associate Data Scientist
# 2                                       Data Scientist
# 3                                 Data Scientist I, II
# 4                                       Data Scientist
# ..                                                 ...
# 600                     Senior Data Scientist (AdTech)
# 601  Junior Research Engineer - Machine Learning Sy...
# 602                              Senior Data Scientist
# 603    Machine Learning Engineer - Foundational Models
# 604               Biomedical Machine Learning Engineer
#
#                                               company            location  \
# 0                        Growers Edge Financial, Inc.              Remote
# 1                                            i2c inc.    Redwood City, CA
# 2                                          TransUnion    White Plains, NY
# 3    First Financial Federal Credit Union of Maryland  Sparks Glencoe, MD
# 4                                  The Columbia Group      Washington, DC
# ..                                                ...                 ...
# 600                                            Nexxen       United States
# 601                             University at Buffalo         Buffalo, NY
# 602                      Constellation Software, Inc.        New York, NY
# 603                                        Stitch Fix              Remote
# 604                                    Analog Devices      Wilmington, MA
#
#                salary  rating  hourly   min_sal   max_sal  avg_salary  \
# 0    100000 - 120000      4.6       0  100000.0  120000.0    110000.0
# 1     90000 - 141000      3.5       0   90000.0  141000.0    115500.0
# 2     68000 - 113000      3.7       0   68000.0  113000.0     90500.0
# 3    108000 - 160000      4.3       0  108000.0  160000.0    134000.0
# 4    101000 - 148000      4.0       0  101000.0  148000.0    124500.0
# ..                ...     ...     ...       ...       ...         ...
# 600  160000 - 210000      3.6       0  160000.0  210000.0    185000.0
# 601   80000 - 100000      4.3       0   80000.0  100000.0     90000.0
# 602  165000 - 185000      4.1       0  165000.0  185000.0    175000.0
# 603  132000 - 194000      3.2       0  132000.0  194000.0    163000.0
# 604  109000 - 150000      3.8       0  109000.0  150000.0    129500.0
#
#                city   state        job_simp job_seniority
# 0            Remote  Remote  data scientist            na
# 1      Redwood City      CA  data scientist            na
# 2      White Plains      NY  data scientist            na
# 3    Sparks Glencoe      MD  data scientist            na
# 4        Washington      DC  data scientist            na
# ..              ...     ...             ...           ...
# 600   United States  Remote  data scientist        senior
# 601         Buffalo      NY             mle            na
# 602        New York      NY  data scientist        senior
# 603          Remote  Remote             mle            na
# 604      Wilmington      MA             mle            na
#
# [605 rows x 13 columns]>

# %%
df.title
# Out:
# 0                                    Risk Data Scientist
# 1                               Associate Data Scientist
# 2                                         Data Scientist
# 3                                   Data Scientist I, II
# 4                                         Data Scientist
#                              ...
# 600                       Senior Data Scientist (AdTech)
# 601    Junior Research Engineer - Machine Learning Sy...
# 602                                Senior Data Scientist
# 603      Machine Learning Engineer - Foundational Models
# 604                 Biomedical Machine Learning Engineer
# Name: title, Length: 605, dtype: object

# %%
df.describe()
# Out:
#            rating      hourly        min_sal        max_sal     avg_salary
# count  605.000000  605.000000     605.000000     605.000000     605.000000
# mean     3.391074    0.064463  106528.096298  158895.453025  132707.540223
# std      1.421332    0.245779   46050.814871   80763.790823   60244.441904
# min     -1.000000    0.000000      16.000000      28.000000      14.000000
# 25%      3.400000    0.000000   83000.000000  121000.000000  104000.000000
# 50%      3.700000    0.000000  104000.000000  151000.000000  130000.000000
# 75%      4.100000    0.000000  132000.000000  189000.000000  160000.000000
# max      5.000000    1.000000  325000.000000  750000.000000  450000.000000

# %%
df.columns
# Out:
# Index(['title', 'company', 'location', 'salary', 'rating', 'hourly', 'min_sal',
#        'max_sal', 'avg_salary', 'city', 'state', 'job_simp', 'job_seniority'],
#       dtype='object')

# %%
df.rating.hist()
# Out:
# <Axes: >

# %%
df.salary.hist()
# Out:
# <Axes: >

# %%
df.avg_salary.hist()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['title', 'company', 'location', 'salary', 'rating', 'hourly', 'min_sal',
#        'max_sal', 'avg_salary', 'city', 'state', 'job_simp', 'job_seniority'],
#       dtype='object')

# %%
df.boxplot(column=['rating'])
# Out:
# <Axes: >

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['avg_salary', 'rating']].corr(), vmax=.3, center=0, cmap=cmap, square=True, linewidths=.5, cbar_kws={'shrink': .5})
# Out:
# <Axes: >

# %% [markdown]
# # Assistant
# The error occurs because there's an unterminated string literal in your code. Specifically, there's a missing opening quote before 'avg_salary'.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# yes

# %%
df.columns
# Out:
# Index(['title', 'company', 'location', 'salary', 'rating', 'hourly', 'min_sal',
#        'max_sal', 'avg_salary', 'city', 'state', 'job_simp', 'job_seniority'],
#       dtype='object')

# %%
df_cat=df[['min_sal','max_sal','avg_salary','rating']]

# %%
for i in df_cat:
    cat_nums=df_cat[i].value_counts()
    sns.barplot(x=cat_nums.index,y=cat_nums)
    plt.show()

# %%
df_cat=df[['min_sal','max_sal','avg_salary','rating']]

# %%
print(df_cat)
# Out:
#       min_sal   max_sal  avg_salary  rating
# 0    100000.0  120000.0    110000.0     4.6
# 1     90000.0  141000.0    115500.0     3.5
# 2     68000.0  113000.0     90500.0     3.7
# 3    108000.0  160000.0    134000.0     4.3
# 4    101000.0  148000.0    124500.0     4.0
# ..        ...       ...         ...     ...
# 600  160000.0  210000.0    185000.0     3.6
# 601   80000.0  100000.0     90000.0     4.3
# 602  165000.0  185000.0    175000.0     4.1
# 603  132000.0  194000.0    163000.0     3.2
# 604  109000.0  150000.0    129500.0     3.8
#
# [605 rows x 4 columns]

# %%
pd.pivot_table(df,index='job_simp',values='avg_salary')
# Out:
#                       avg_salary
# job_simp
# analyst             77458.891111
# data engineer      154000.000000
# data scientist     132336.386748
# manager            130000.000000
# mle                167472.187500
# na                 129333.796957
# research position  201004.666667

# %%
pd.pivot_table(df,index=['job_simp','job_seniority'],values='avg_salary')
# Out:
#                                     avg_salary
# job_simp          job_seniority
# analyst           na              91250.000000
#                   senior          66426.004000
# data engineer     na             154000.000000
# data scientist    jr              48523.115000
#                   na             127769.515623
#                   senior         146772.392660
# manager           na             130000.000000
# mle               na             167472.187500
# na                na             124877.754211
#                   senior         150500.000000
# research position na             201004.666667

# %%
pd.pivot_table(df,index=df.location,values='avg_salary').sort_values('avg_salary',ascending=False)[0:20]
# Out:
#                       avg_salary
# location
# Redwood City, CA   249750.000000
# Cupertino, CA      223600.000000
# San Francisco, CA  211344.827586
# Menlo Park, CA     206800.000000
# Hoboken, NJ        198000.000000
# Nashville, TN      195500.000000
# Renton, WA         193500.000000
# Mountain View, CA  192666.666667
# Seattle, WA        184055.555556
# Palo Alto, CA      183818.181818
# Laguna Hills, CA   183000.000000
# Irvine, CA         176000.000000
# Pleasanton, CA     175833.333333
# San Jose, CA       174147.058824
# Redmond, WA        173500.000000
# Frisco, TX         172250.000000
# California         171250.000000
# McLean, VA         167750.000000
# Carson City, NV    167500.000000
# Oceanport, NJ      167500.000000

# %%
pd.pivot_table(df,index=df.state,values='avg_salary').sort_values('avg_salary',ascending=False)
# Out:
#            avg_salary
# state
#  CA     168918.250438
#  WA     161875.000000
#  IA     147500.000000
#  NY     143642.857143
# Remote  141104.892135
#  HI     140000.000000
#  TN     136833.333333
#  IN     135400.000000
#  SC     132250.000000
#  DC     131447.368421
#  MO     127250.000000
#  ME     126500.000000
#  NV     124500.000000
#  AR     119875.000000
#  VA     119865.521667
#  MA     119730.681818
#  IL     119145.833333
#  CT     119000.000000
#  WI     118333.333333
#  UT     118166.666667
#  OK     116000.000000
#  CO     115740.035526
#  MD     113441.533929
#  PR     113375.000000
#  MN     112000.000000
#  AZ     111793.571429
#  NE     109500.000000
#  OR     108500.000000
#  OH     106772.727273
#  TX     106214.239744
#  MI     106000.000000
#  PA     105542.307692
#  NJ     104172.038947
#  NH     104000.000000
#  NC      92091.443333
#  AL      89500.000000
#  FL      85156.428571
#  GA      79122.318250
#  KY      63000.000000
#  NM      58000.000000
#  LA         30.900000

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.set_option('display.max_rows',None)

# %%
pd.pivot_table(df,index=[df.state,'job_seniority'],values='avg_salary',aggfunc='count').sort_values('avg_salary',ascending=False)
# Out:
#                       avg_salary
# state  job_seniority
#  CA    na                     96
# Remote na                     63
#  CA    senior                 41
# Remote senior                 33
#  NY    na                     31
#  VA    na                     30
#  TX    na                     28
#  IL    na                     18
#  WA    na                     17
#  OH    na                     16
#  DC    na                     16
#  NJ    na                     15
#  MD    na                     13
#  GA    na                     13
#  PA    na                     13
#  CO    na                     12
#  MA    na                     11
#  NY    senior                 11
#  TX    senior                 10
#  GA    senior                  7
#  UT    na                      7
#  CO    senior                  7
#  FL    na                      6
#  OH    senior                  6
#  IL    senior                  6
#  AZ    na                      5
#  NC    na                      5
#  MN    na                      4
#  PR    na                      3
#  NJ    senior                  3
#  AR    na                      3
#  VA    senior                  3
#  MO    na                      3
#  MI    na                      3
#  WA    senior                  3
#  DC    senior                  3
#  IN    na                      3
#  TN    na                      2
#  WI    na                      2
#  UT    senior                  2
#  AL    na                      2
#  NM    na                      2
#  AZ    senior                  2
#  IN    senior                  2
#  NV    senior                  1
#  TX    jr                      1
#  AR    senior                  1
#  WI    senior                  1
#  CT    na                      1
#  FL    senior                  1
#  HI    na                      1
#  IA    na                      1
#  KY    na                      1
#  LA    na                      1
#  MD    senior                  1
#  TN    senior                  1
#  NV    na                      1
#  ME    na                      1
#  SC    senior                  1
#        na                      1
#  PR    senior                  1
#  MO    senior                  1
#  NC    senior                  1
#  OR    na                      1
#  OK    senior                  1
#  NH    na                      1
#  NJ    jr                      1
#  NE    na                      1

# %%
df.columns
# Out:
# Index(['title', 'company', 'location', 'salary', 'rating', 'hourly', 'min_sal',
#        'max_sal', 'avg_salary', 'city', 'state', 'job_simp', 'job_seniority'],
#       dtype='object')

# %%
df_pivot=df[['rating','hourly','company','avg_salary']]

# %%
for i in df_pivot:
    print(i)
    print(pd.pivot_table(df_pivot,index=i,values='avg_salary').sort_values('avg_salary',ascending=False))
# Out:
# rating
#            avg_salary
# rating
#  4.5    246458.333333
#  3.2    162062.500000
#  4.2    156310.979130
#  2.0    155000.000000
#  4.4    153142.083333
#  2.8    150083.333333
#  2.3    146500.000000
#  3.7    143269.230769
#  4.0    141188.764706
#  4.1    140746.636889
#  4.3    138895.833333
#  3.9    136682.090238
#  4.7    134687.500000
#  3.8    134126.524694
#  3.4    131302.833333
#  2.9    130250.000000
#  3.5    130137.193182
#  3.3    128578.947368
#  1.0    125500.000000
#  3.0    125000.000000
#  3.6    122268.259348
#  5.0    118397.857143
#  2.6    109000.000000
#  2.5    105000.000000
#  3.1    103943.134375
#  4.8    103725.785714
#  4.9    102500.000000
#  2.7     99500.000000
# -1.0     87380.914608
#  4.6     84512.905000
#  2.4     59024.166667
# hourly
#            avg_salary
# hourly
# 0       141847.173145
# 1           65.688077
# company
#                                                      avg_salary
# company
# Netflix                                           446666.666667
# Equinix                                           384000.000000
# OpenAI                                            337916.666667
# Tesla                                             280000.000000
# Reddit                                            244750.000000
# Northrop Grumman                                  235000.000000
# Parafin                                           232500.000000
# Apple                                             225437.500000
# Rivian and VW Group Technology                    224000.000000
# Waymo                                             222000.000000
# iHerb                                             221000.000000
# TikTok                                            219200.000000
# Genentech                                         211000.000000
# Eli Lilly                                         210000.000000
# Rivian                                            209500.000000
# Meta                                              209000.000000
# GoFundMe                                          208500.000000
# PayPal                                            207500.000000
# Uniswap Labs                                      206000.000000
# Creative Artists Agency (CAA)                     204500.000000
# Intuit                                            203500.000000
# Gap Inc.                                          202500.000000
# Spirent                                           202000.000000
# Tandem                                            200000.000000
# Suno                                              200000.000000
# Abridge Al                                        200000.000000
# Chicago Trading Company (CTC)                     200000.000000
# Astrana Health, Inc.                              200000.000000
# Salesforce                                        197500.000000
# DoorDash                                          197500.000000
# Twitch Interactive, Inc.                          195500.000000
# Hasbro Inc.                                       193500.000000
# Roku                                              193000.000000
# Glean Technologies                                192500.000000
# Kaiser Permanente                                 190500.000000
# Dropbox                                           190375.000000
# Ironclad, Inc.                                    190000.000000
# JTEC Consulting                                   190000.000000
# Greater New York Mutual Insurance Company         189000.000000
# Flock Safety                                      187500.000000
# Robinhood                                         186250.000000
# Wealthfront                                       185750.000000
# paypal                                            185666.666667
# SoFi                                              185250.000000
# Angi                                              185000.000000
# Cint                                              183500.000000
# Cedars-Sinai                                      183000.000000
# Walmart                                           183000.000000
# HTN Wireless                                      183000.000000
# Augmodo                                           182500.000000
# JY Systems LLC                                    180000.000000
# Amida Technology Solutions                        180000.000000
# Halvik                                            180000.000000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 3
#       1 for i in df_pivot:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivot,index=i,values='avg_salary').sort_values('avg_salary',ascending=False))
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/reshape/pivot.py:172, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     169     values = list(values)
#     171 observed_bool = False if observed is lib.no_default else observed
# --> 172 grouped = data.groupby(keys, observed=observed_bool, sort=sort, dropna=dropna)
#     173 if observed is lib.no_default and any(
#     174     ping._passed_categorical for ping in grouped._grouper.groupings
#     175 ):
#     176     warnings.warn(
#     177         "The default value of observed=False is deprecated and will change "
#     178         "to observed=True in a future version of pandas. Specify "
#    (...)
#     181         stacklevel=find_stack_level(),
#     182     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/groupby/grouper.py:1038, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1034     in_axis, name, gpr = True, gpr, obj[gpr]
#    1035     if gpr.ndim != 1:
#    1036         # non-unique columns; raise here to get the name in the
#    1037         # exception message
# -> 1038         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#    1039     exclusions.add(name)
#    1040 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'avg_salary' not 1-dimensional

# %%
# !pip install wordcloud
from wordcloud import WordCloud

text = "Data science is amazing. Data, data, data. Science is fun."

# Generate a word cloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # no axis
plt.show()
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /opt/anaconda3/lib/python3.13/site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.13/site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp313-cp313-macosx_11_0_arm64.whl (167 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
from wordcloud import WordCloud

text = "Data science is amazing. Data, data, data. Science is fun."

# Generate a word cloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # no axis
plt.show()
